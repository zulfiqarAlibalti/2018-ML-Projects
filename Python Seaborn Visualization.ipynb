# %% [markdown]
# # Python Seaborn Visualization
#
# ### Introdution to seborn
#
# used for visualization and based on **matplotlib** seaborn allows the creation of stattistical graphics
#
# ### Functionalities
#
# Allow cpmpression between varibales
#
# support multi-plot grids
#
# Available univarite and bivariate visualizations
#
# Availability of different colour pattern
#
# Estimates and plot linear regression automatically.
#
#  ### Seaborn Vs Matplotlib
#
#  Seaborn fixes two short comings of matplotlib:
#
#  Matplotlib settings are difficult to figure outt Seaborn comes with numerous customized themes and high-level inteface.
#
#  Matplotlib doesn't serve well when it comes to dealing with DataFrame while Seaborn functions actually work on DataFrames.
#
#  ** pip install seaborn**
#
#    ### Installing Dpendencies
#
#    Numpy , Scipy ,Matplotlib ,Pandas SM Statistical Model in Python.
#
#  ## Python Seborn Functions
#
#  Visualize Statistical Relationships .
#
#  Process of unberstanding relationships between variables of a dataset.
#
#  ### Plot with Catogorical Data
#
#  Main variable is further divided into discrete groups.
#
#  ### Visualization the distribution of a dataset.
#
#  Understanding datasets with context to being univariate or bivariate.

# %%
## Python Seaborn

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
a = sns.load_dataset("flights")
a
# Out:
#      year      month  passengers
# 0    1949    January         112
# 1    1949   February         118
# 2    1949      March         132
# 3    1949      April         129
# 4    1949        May         121
# ..    ...        ...         ...
# 139  1960     August         606
# 140  1960  September         508
# 141  1960    October         461
# 142  1960   November         390
# 143  1960   December         432
#
# [144 rows x 3 columns]

# %%
sns.relplot(x ="passengers" ,y="month" ,data =a)

# %%
b= sns.load_dataset("tips")
b
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.relplot(x ="time",y= "tip" ,data =b ,kind="line")

# %%
##PLoting with Catgorical Data

# %%
sns.catplot(x ="day",y ="total_bill",data=b)

# %%
sns.catplot(x ="day" ,y ="total_bill",kind="violin" ,data =b)

# %%
sns.catplot(x ="day" ,y ="total_bill",kind="boxen" ,data =b)

# %%
## 3.Visualizing the Distribution

# %%
## univariate

# %%
from scipy import stats

# %%
c= np.random.normal(loc =5 ,size=100 ,scale =2)

# %%
sns.distplot(c)

# %%
##Multivariate

# %%
x =pd.DataFrame({'Day' :[1,2,3,4,5,6,7] ,'Grocery':[30 ,80 ,45 ,23 ,51,46 ,75] ,'Clothes':[13 ,40 ,34 ,23 ,54 ,67 ,98] ,'Utensils':
                 [12,32 ,27,34,56,76,23]})

# %%
y = pd.DataFrame({'Day' :[8,9,10,11,12,13,14] ,'Grocery':[30 ,80 ,45 ,23 ,51,46 ,75] ,'Clothes':[13 ,40 ,34 ,23 ,54 ,67 ,98] ,'Utensils':
                 [12,14 ,27,12,15,76,23]})

# %%
mean  ,cov = [0,1],[(1,.5),(.5,1)]
data = np.random.multivariate_normal(mean  ,cov,200)

# %%
with sns.axes_style("white"):
    sns.jointplot(x =x ,y=y ,kind="kde",color="b");

# %% [markdown]
# ### Multiplot grids
#
# Graph are plotted side using the same scale and axes to aid compresion

# %%
a = sns.load_dataset("iris")
b = sns.FacetGrid(a,col="species")
b.map(plt.hist,"sepal_length")

# %%
import matplotlib.pyplot as plt

# %%
a = sns.load_dataset("flights")
b = sns.PairGrid(a)
b.map(plt.scatter)

# %% [markdown]
# ## Plot Asthetics
#
# Deals with making our plot more attractive and delightfull.

# %%
sns.set(style="darkgrid")
a = sns.load_dataset("flights")
b= sns.PairGrid(a)
b.map(plt.scatter)

# %%
sns.set(style="white",color_codes =True)

# %%
a = sns.load_dataset("tips")

# %%
sns.boxplot(x="day",y ="total_bill" ,data=a)

# %%
a = sns.load_dataset("tips")
sns.despine(offset=10,trim =True )

# %%
a = sns.color_palette()
sns.palplot(a)
